# %%
# !pip install opencv-python
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2 as cv
import os

# %%
# создем модель с готовыми весами
model = YOLO("yolo11s.pt")
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 38.8MB/s]

# %%
# путь к видео на вход
path_in = "/kaggle/input/birdie/video.mp4"
# путь к видео на выход
path_out = "birdie_out.mp4"

# %%
# для захвата видео
cap = cv.VideoCapture(path_in)

# FPS
fps = int(cap.get(cv.CAP_PROP_FPS))
# ширина
width = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
# высота
height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
# кодек
fourcc = cv.VideoWriter_fourcc(*'mp4v')

# для записи результирующего видео
out = cv.VideoWriter(path_out, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    
    # проверяем, что картинка доступна
    if not ret:
        break

    # детектим объекты
    results = model(
        frame,  # текущий кадр
        verbose=False   # прячем неимоверно длинный отчет о результатах
    )

    # аннотируем
    annotated_frame = results[0].plot()  # получаем кадр с bbox

    # Запись кадра в выходное видео
    out.write(annotated_frame)

# Закрытие ресурсов
cap.release()
out.release()

# %%
# новая моделька
model = YOLO("yolo11x.pt")
# Out:
# ...
# 100%|██████████| 109M/109M [00:01<00:00, 69.0MB/s]

# %%
# конфигурационный файл датасета
yaml = "/kaggle/input/cardetection/car/data.yaml"

# тренируем мильён лет 😭😭😭😭 
results = model.train(data=yaml, epochs=20)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
path_in = "/kaggle/input/cardetection/video.mp4"
path_out = "signs_out.mp4"

# %%
# для захвата видео
cap = cv.VideoCapture(path_in)

# FPS
fps = int(cap.get(cv.CAP_PROP_FPS))
# ширина
width = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
# высота
height = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
# кодек
fourcc = cv.VideoWriter_fourcc(*'mp4v')

# для записи результирующего видео
out = cv.VideoWriter(path_out, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    
    # проверяем, что картинка доступна
    if not ret:
        break

    # детектим объекты
    results2 = model(
        frame,  # текущий кадр
        verbose=False   # прячем неимоверно длинный отчет о результатах
    )

    # аннотируем
    annotated_frame = results2[0].plot()  # получаем кадр с bbox

    # Запись кадра в выходное видео
    out.write(annotated_frame)

# Закрытие ресурсов
cap.release()
out.release()
